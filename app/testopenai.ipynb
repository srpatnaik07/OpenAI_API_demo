# %%
import openai
from dotenv import load_dotenv
import pandas as pd

# %%
openai.api_key='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'

# %%
pd.DataFrame(openai.Model.list()['data'])
# Out:
#                                id object     created         owned_by  \
# 0                       whisper-1  model  1677532384  openai-internal
# 1                         babbage  model  1649358449           openai
# 2                text-davinci-003  model  1669599635  openai-internal
# 3                         davinci  model  1649359874           openai
# 4           text-davinci-edit-001  model  1649809179           openai
# 5        babbage-code-search-code  model  1651172509       openai-dev
# 6     text-similarity-babbage-001  model  1651172505       openai-dev
# 7           code-davinci-edit-001  model  1649880484           openai
# 8                text-davinci-001  model  1649364042           openai
# 9                             ada  model  1649357491           openai
# 10       babbage-code-search-text  model  1651172509       openai-dev
# 11             babbage-similarity  model  1651172505       openai-dev
# ...

# %%
## Chat completion API and Completion API

#Completion API
response = openai.Completion.create(
    model = 'text-curie-001',
    prompt = "Explain Machine Learning to a ten years old",
    max_tokens=25
)
response
# Out:
# <OpenAIObject text_completion id=cmpl-7bliYYuLLWAWJ9U2iGbAwyqkw64wk at 0x261d29133b0> JSON: {
#   "id": "cmpl-7bliYYuLLWAWJ9U2iGbAwyqkw64wk",
#   "object": "text_completion",
#   "created": 1689235918,
#   "model": "text-curie-001",
#   "choices": [
#     {
#       "text": "\n\nMachine learning is a field of computer science and engineering that deals with the design and implementation of algorithms that allow computers to",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 9,
#     "completion_tokens": 25,
#     "total_tokens": 34
#   }
# }

# %%
response = openai.Completion.create(
    model = 'text-curie-001',
    prompt = "Compare between Messi and Cristiano Ronaldo",
    max_tokens = 100,
    temperature=0.6,
    n=5,
)
response
# Out:
# <OpenAIObject text_completion id=cmpl-7bliYQO22ldJrc7A4n8BJfhJERcIA at 0x261d2814e90> JSON: {
#   "id": "cmpl-7bliYQO22ldJrc7A4n8BJfhJERcIA",
#   "object": "text_completion",
#   "created": 1689235918,
#   "model": "text-curie-001",
#   "choices": [
#     {
#       "text": "\n\nThere is no clear answer as to who is better between Messi and Ronaldo. They are both world-class players and have been able to amass massive personal wealth and fan bases. However, there are some key differences between the two that could tilt the scales in one direction or another.\n\nFor one, Ronaldo is a more consistent goal scorer, with an average of 41 goals per season compared to Messi\u2019s 36. Ronaldo also tends to create more chances, with an average of",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     },
#     {
#       "text": "\n\nThere is no comparison between Messi and Ronaldo. Messi is a pure genius while Ronaldo is a world-class superstar.",
# ...

# %%
print(response['choices'][0]['text'])
# Out:
# There is no clear answer as to who is better between Messi and Ronaldo. They are both world-class players and have been able to amass massive personal wealth and fan bases. However, there are some key differences between the two that could tilt the scales in one direction or another.
#
# For one, Ronaldo is a more consistent goal scorer, with an average of 41 goals per season compared to Messi’s 36. Ronaldo also tends to create more chances, with an average of

# %%
print(response['choices'][2]['text'])
# Out:
# Both Messi and Ronaldo are world-class footballers. However, there are a few key differences between them. For one, Ronaldo is more of a goal scorer, with Messi being more of a creator. Additionally, Ronaldo is more physical, while Messi is more technical.

# %%
response = openai.Completion.create(
    model = "text-davinci-003",
    prompt = """Act as an AI model to detect positive or negative tweets:
    Arnab Goswami is a very biased and arrogant reporter""",
    max_tokens = 15,
    temperature = 1,
    n =1

)
print(response)
# Out:
# {
#   "id": "cmpl-7blia0mnuyvYfrnwXJlGYbDPfz6G8",
#   "object": "text_completion",
#   "created": 1689235920,
#   "model": "text-davinci-003",
#   "choices": [
#     {
#       "text": "\n\nNegative",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 26,
#     "completion_tokens": 4,
#     "total_tokens": 30
#   }
# }

# %%
response = openai.Completion.create(
    model = "text-davinci-003",
    prompt = """ Act as an AI model to  translate text to French:
    "Hello, how are you?"
    """,
    max_tokens = 15,
    temperature = 1
)
print(response)
# Out:
# {
#   "id": "cmpl-7blibJ8VigBY083zCkJahN61hmveW",
#   "object": "text_completion",
#   "created": 1689235921,
#   "model": "text-davinci-003",
#   "choices": [
#     {
#       "text": "\nBonjour, comment vas-tu ?",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 23,
#     "completion_tokens": 10,
#     "total_tokens": 33
#   }
# }

# %%
## ChatCompletion API
openai.ChatCompletion.create(
    model = 'gpt-3.5-turbo',
    messages = [{'role':'system','content':"Act as an AI Assistant"},
                {'role':'user','content':"Hello, how are you"}]
)
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7blidTmreAlR7Z64RtR4TL1yWednf at 0x261d28cfb30> JSON: {
#   "id": "chatcmpl-7blidTmreAlR7Z64RtR4TL1yWednf",
#   "object": "chat.completion",
#   "created": 1689235923,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Hello! As an AI assistant, I don't have feelings, but I'm here to help. How can I assist you today?"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 27,
#     "total_tokens": 48
#   }
# }

# %% [markdown]
# # Function Calling using OpenAI API

# %%
import openai
openai.api_key = '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'

# %%
completion = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","content":"You are an assistant which informs about temperature."},
        {"role":"user","content":"Hello API"}
    ]
)

# %%
completion
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7blieIFsO0sLjvfz05iqLWKZq0s9G at 0x261d2815250> JSON: {
#   "id": "chatcmpl-7blieIFsO0sLjvfz05iqLWKZq0s9G",
#   "object": "chat.completion",
#   "created": 1689235924,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Hello! How can I assist you today?"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 22,
#     "completion_tokens": 9,
#     "total_tokens": 31
#   }
# }

# %%
print(completion.choices[0].message)
# Out:
# {
#   "role": "assistant",
#   "content": "Hello! How can I assist you today?"
# }

# %%
import requests
import json

def get_current_weather(location):
    """Get the current weather in a location"""
    url = "https://ai-weather-by-meteosource.p.rapidapi.com/find_places"

    querystring = {"text":location}

    headers = {
	"X-RapidAPI-Key": "48e9adc3e6msh726472b5cde930ap14b598jsndc600ef87d6b",
	"X-RapidAPI-Host": "ai-weather-by-meteosource.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)
    
    print(type(response))

    return response.json()

# %%
response = get_current_weather('Bengaluru')
# Out:
# <class 'requests.models.Response'>

# %%
response
# Out:
# [{'name': 'Bengaluru',
#   'place_id': 'bengaluru',
#   'adm_area1': 'Karnataka',
#   'adm_area2': 'Bengaluru Urban',
#   'country': 'India',
#   'lat': '12.97194N',
#   'lon': '77.59369E',
#   'timezone': 'Asia/Kolkata',
#   'type': 'settlement'},
#  {'name': 'Bengaluru Rural',
#   'place_id': 'bangalore-rural',
#   'adm_area1': 'Karnataka',
#   'adm_area2': 'Bengaluru Rural',
#   'country': 'India',
#   'lat': '13.22567N',
#   'lon': '77.57501E',
#   'timezone': 'Asia/Kolkata',
#   'type': 'administrative_area'},
#  {'name': 'Bengaluru Urban',
#   'place_id': 'bangalore-urban',
#   'adm_area1': 'Karnataka',
#   'adm_area2': 'Bengaluru Urban',
#   'country': 'India',
#   'lat': '13.0N',
#   'lon': '77.58333E',
#   'timezone': 'Asia/Kolkata',
#   'type': 'administrative_area'},
#  {'name': 'Kempegowda International Airport',
#   'place_id': 'kempegowda-international-airport',
#   'adm_area1': 'Karnataka',
#   'adm_area2': 'Bengaluru Rural',
#   'country': 'India',
# ...

# %%
functions = [
        {
            "name": "get_current_weather",
            "description": "Get the current weather in a given location",
            "parameters": {
                "type": "object",
                "properties": {
                    "location": {
                        "type": "string",
                        "description": "The city and state, e.g. San Francisco, CA",
                    },
                    "unit": {"type": "string", "enum": ["celsius", "fahrenheit"]},
                },
                "required": ["location"],
            },
        }
    ]

# %%
functions
# Out:
# [{'name': 'get_current_weather',
#   'description': 'Get the current weather in a given location',
#   'parameters': {'type': 'object',
#    'properties': {'location': {'type': 'string',
#      'description': 'The city and state, e.g. San Francisco, CA'},
#     'unit': {'type': 'string', 'enum': ['celsius', 'fahrenheit']}},
#    'required': ['location']}}]

# %%
user_message = "Hi there"
messages = []
messages.append({"role":"user","content":user_message})
completion = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = messages
)

# %%
print(completion.choices[0].message)
# Out:
# {
#   "role": "assistant",
#   "content": "Hello! How can I assist you today?"
# }

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Hi there'}]

# %%
user_message = "What is the temperature of Lucknow?"
messages.append({"role":"user","content":user_message})
completion = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo-0613",
    messages= messages,
    functions = functions
)

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Hi there'},
#  {'role': 'user', 'content': 'What is the temperature of Lucknow?'}]

# %%
completion
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7bmLsSEWUS1BXsKfUOrdBCi2d7JcN at 0x261d2814590> JSON: {
#   "id": "chatcmpl-7bmLsSEWUS1BXsKfUOrdBCi2d7JcN",
#   "object": "chat.completion",
#   "created": 1689238356,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": null,
#         "function_call": {
#           "name": "get_current_weather",
#           "arguments": "{\n  \"location\": \"Lucknow\"\n}"
#         }
#       },
#       "finish_reason": "function_call"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 88,
#     "completion_tokens": 17,
#     "total_tokens": 105
#   }
# }

# %%
print(completion.choices[0].message)
# Out:
# {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "get_current_weather",
#     "arguments": "{\n  \"location\": \"Lucknow\"\n}"
#   }
# }

# %%
response = completion.choices[0].message

# %%
response
# Out:
# <OpenAIObject at 0x261d297bc50> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "get_current_weather",
#     "arguments": "{\n  \"location\": \"Lucknow\"\n}"
#   }
# }

# %%
function_name=response['function_call']['name']
print(function_name)
# Out:
# get_current_weather

# %%
import json
location=eval(response['function_call']['arguments'])['location']
print(location)
# Out:
# Lucknow

# %%
# Step 4: send the info on the function call and function response to GPT
messages.append(response)  # extend conversation with assistant's reply
messages.append(
    {
        "role": "function",
        "name": function_name,
        "content": location,
    }
)

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Hi there'},
#  {'role': 'user', 'content': 'What is the temperature of Lucknow?'},
#  <OpenAIObject at 0x261d297bc50> JSON: {
#    "role": "assistant",
#    "content": null,
#    "function_call": {
#      "name": "get_current_weather",
#      "arguments": "{\n  \"location\": \"Lucknow\"\n}"
#    }
#  },
#  {'role': 'function', 'name': 'get_current_weather', 'content': 'Lucknow'}]

# %%
# extend conversation with function response
second_response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo-0613",
    messages=messages,
    functions=functions
)  # get a new response from GPT where it can see the function response

# %%
print(second_response.choices[0].message)
# Out:
# {
#   "role": "assistant",
#   "content": "The current temperature in Lucknow is 32 degrees Celsius."
# }
